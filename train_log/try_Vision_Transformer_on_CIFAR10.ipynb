# %% [markdown]
# <a href="https://colab.research.google.com/github/fangpin/dlutil/blob/main/train_log/try_Vision_Transformer_on_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/fangpin/dlutil.git
# %cd /content/dlutil
# !git pull
# !pip install -r requirements.txt

# %%
# %cd /root/dlutil
# !python3 -m dlutil.models.vision_transfomer
# Out:
# /root/dlutil
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Device: cuda:0
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3195146
# 351it [00:18, 18.50it/s]
# train avg loss 1.7990299918373087, val avg loss 1.509366261959076, val correct rate 0.45479997992515564 at epoch 0
# 351it [00:19, 18.41it/s]
# train avg loss 1.5104659870479182, val avg loss 1.3660827666521071, val correct rate 0.5101999640464783 at epoch 1
# 351it [00:18, 18.91it/s]
# train avg loss 1.3924841890987167, val avg loss 1.2298631340265274, val correct rate 0.5573999881744385 at epoch 2
# 351it [00:18, 18.81it/s]
# train avg loss 1.3271734442805971, val avg loss 1.1754168048501015, val correct rate 0.5726000070571899 at epoch 3
# 351it [00:18, 18.93it/s]
# ...

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %cd /root/logs/ViT
# %tensorboard --logdir . --bind_all --port 9002
# Out:
# /root/logs/ViT
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Reusing TensorBoard on port 9002 (pid 997), started 0:00:45 ago. (Use '!kill 997' to kill it.)
#       <iframe id="tensorboard-frame-4bd58785ad0b4b8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4bd58785ad0b4b8");
#           const url = new URL("http://localhost");
#           const port = 9002;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
